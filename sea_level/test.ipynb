# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df=pd.read_csv('epa-sea-level.csv')
df.head(1)
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                       0.0          -0.952756           0.952756
#
#    NOAA Adjusted Sea Level
# 0                      NaN

# %%
fig=plt.figure(figsize=(10,10))
plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])

# %%
model=linregress(df['Year'],df['CSIRO Adjusted Sea Level'])
print(model.stderr)
# Out:
# 0.0009692118713287152

# %%
pendiente=model.slope
intercept=model.intercept
df_2=df[df['Year']>=2000]
model1=linregress(df_2['Year'],df_2['CSIRO Adjusted Sea Level'])
pendiente1=model1.slope
intercept1=model1.intercept
fig=plt.figure(figsize=(10,10))
plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])
plt.plot(df['Year'],pendiente*df['Year']+intercept,label='fitted line',color='green')
plt.plot(df_2['Year'],pendiente1*df_2['Year']+intercept1,label='fitted line',color='black')
plt.plot(2050,pendiente*2050+intercept,'ro',label='2050')

# %%
df_2=df[df['Year']>=2000]
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 120 to 133
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      14 non-null     int64
#  1   CSIRO Adjusted Sea Level  14 non-null     float64
#  2   Lower Error Bound         14 non-null     float64
#  3   Upper Error Bound         14 non-null     float64
#  4   NOAA Adjusted Sea Level   14 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 672.0 bytes

# %%
model1=linregress(df_2['Year'],df_2['CSIRO Adjusted Sea Level'])
pendiente1=model1.slope
intercept1=model1.intercept
print(model1.stderr)
fig=plt.figure(figsize=(10,10))
plt.scatter(df_2['Year'],df_2['CSIRO Adjusted Sea Level'])
plt.plot(df_2['Year'],pendiente1*df_2['Year']+intercept1,label='fitted line')
plt.plot(2050,pendiente1*2050+intercept1,'ro',label='2050')
# Out:
# 0.010652933111541163

# %%
df_1=df.copy()
df_1=df_1.drop('NOAA Adjusted Sea Level',axis=1)
df_1
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
# [134 rows x 4 columns]

# %%
    df=pd.read_csv('epa-sea-level.csv')
    df.head()
    
    # Create scatter plot

    fig=plt.figure(figsize=(10,10))
    plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])
    
    # Create first line of best fit

    model=linregress(df['Year'],df['CSIRO Adjusted Sea Level'])
    pendiente=model.slope
    intercept=model.intercept
    plt.plot(df['Year'],pendiente*df['Year']+intercept,label='fitted line',color='green')
    
    # Create second line of best fit
    df_2=df[df['Year']>=2000]
    model1=linregress(df_2['Year'],df_2['CSIRO Adjusted Sea Level'])
    pendiente1=model1.slope
    intercept1=model1.intercept
    plt.plot(df_2['Year'],pendiente1*df_2['Year']+intercept1,label='fitted line',color='black')
    plt.plot(2050,pendiente*2050+intercept,'ro',label='2050')
    plt.xlabel('Year')
    plt.ylabel('Sea Level (inches)')
    plt.title('Rise in Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')
